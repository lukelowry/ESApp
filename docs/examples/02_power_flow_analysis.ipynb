# %% [markdown]
# # Power Flow Analysis
#
# Solves the AC power flow and inspects system voltages for violations.

# %%
from gridwb import *

wb = GridWorkBench(r"case.pwb")
# Out:
# 'open' took: 2.9821 sec

# %%
V = wb.pflow()

# %% [markdown]
# ### Retrieve Voltages

# %% [markdown]
# Then we can check for violations

# %%
low_v = V[abs(V) < 0.98]
len(low_v)
# Out:
# 9

# %% [markdown]
# And find the minimum voltage as follows

# %%
abs(V).min()
# Out:
# np.float64(0.9749114967028367)
