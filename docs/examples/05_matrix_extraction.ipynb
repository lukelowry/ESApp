# %% [markdown]
# # Matrix Extraction
#
# Extracting system matrices (Y-Bus and Jacobian) for external mathematical analysis.

# %%
from gridwb import GridWorkBench

wb = GridWorkBench(r"case.pwb")

Y = wb.ybus()
Y.shape
# Out:
# 'open' took: 3.7408 sec
# (37, 37)

# %% [markdown]
# Which is of the form $(n_{vert}, n_{vert})$.

# %% [markdown]
# ### Incidence Matrix

# %% [markdown]
# Get the incidence matrix of the network in CSC format

# %%
A = wb.network.incidence()
A.shape
# Out:
# (89, 37)

# %% [markdown]
# Which is of the form $(n_{edge}, n_{vert})$.
