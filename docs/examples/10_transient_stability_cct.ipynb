# %% [markdown]
# # Transient Stability and Critical Clearing Time
#
# Automating the calculation of Critical Clearing Time (CCT) for a fault and generating transient response plots to visualize system stability.

# %%
from gridwb import GridWorkBench
from gridwb.grid.components import Branch, Bus
import os


case_path = os.environ.get("SAW_TEST_CASE", "case.pwb")

wb = GridWorkBench(case_path)
# Out:
# 'open' took: 3.0528 sec

# %%
# Initialize Transient Stability
wb.io.esa.TSInitialize()

# Calculate Critical Clearing Time (CCT) for a branch fault
branches = wb[Branch, ['BusNum', 'BusNum:1', 'LineCircuit']]
if not branches.empty:
    b = branches.iloc[0]
    branch_str = f"[BRANCH {b['BusNum']} {b['BusNum:1']} {b['LineCircuit']}]"
    
    wb.io.esa.TSCalculateCriticalClearTime(branch_str)
    cct_val = wb.io.esa.GetParametersSingleElement(
        "Branch", ["TSCritClearTime"], [b['BusNum'], b['BusNum:1'], b['LineCircuit']]
    )
    print(f"Critical Clearing Time: {cct_val:.4f} seconds ({cct_val*60:.1f} cycles)")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[5], line 11
#       8 branch_str = f"[BRANCH {b['BusNum']} {b['BusNum:1']} {b['LineCircuit']}]"
#      10 wb.io.esa.TSCalculateCriticalClearTime(branch_str)
# ---> 11 cct_val = wb.io.esa.GetParametersSingleElement(
#      12     "Branch", ["TSCritClearTime"], [b['BusNum'], b['BusNum:1'], b['LineCircuit']]
#      13 )
#      14 print(f"Critical Clearing Time: {cct_val:.4f} seconds ({cct_val*60:.1f} cycles)")
#
# File ~\Documents\GitHub\ESAplus\gridwb\saw\base.py:749, in SAWBase.GetParametersSingleElement(self, ObjectType, ParamList, Values)
#     722 def GetParametersSingleElement(self, ObjectType: str, ParamList: list, Values: list) -> pd.Series:
#     723     """Retrieves parameters for a single object identified by its primary keys.
#     724
#     725     Parameters
#    (...)    747         If the SimAuto call fails.
#     748     """
# --> 749     assert len(ParamList) == len(Values), "The given ParamList and Values must have the same length."
#     751     output = self._call_simauto(
#     752         "GetParametersSingleElement",
#     753         ObjectType,
#     754         convert_list_to_variant(ParamList),
#     755         convert_list_to_variant(Values),
#     756     )
#     758     s = pd.Series(output, index=ParamList)
#
# AssertionError: The given ParamList and Values must have the same length.

# %%
# Generate and save plots
try:
    wb.esa.TSAutoSavePlots(
        plot_names=["Generator Frequencies", "Bus Voltages"],
        contingency_names=["Fault_at_Bus_1"],
        image_file_type="JPG",
        width=1280,
        height=720
    )
    print("Plots saved to the case's result directory.")
except Exception as e:
    print(f"Plot generation skipped: {e}")
