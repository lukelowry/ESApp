# %% [markdown]
# # Security Constrained OPF (SCOPF)
#
# Finds least-cost dispatch satisfying base-case and N-1 constraints.

# %%
from esapp import GridWorkBench, Area

wb = GridWorkBench(r"case.pwb")
# Out:
# 'open' took: 2.9091 sec

# %% [markdown]
# Setup SCOPF

# %% [markdown]
# Initialize the Primal LP solver and auto-insert single-element contingencies for the SCOPF.

# %%
wb.esa.InitializePrimalLP()
wb.auto_insert_contingencies()

# %% [markdown]
# Solve SCOPF

# %% [markdown]
# Solve the full Security-Constrained Optimal Power Flow.

# %%
wb.esa.SolveFullSCOPF()

wb[Area, "GenProdCost"]
# Out:
#    AreaNum  GenProdCost
# 0        1  4186.789214
